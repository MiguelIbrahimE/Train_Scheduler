# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# Load the Belgian rail layer (adjust path if you've stored it elsewhere)
gdf = gpd.read_file("../data/raw/rail_be.gpkg", layer="rail")

# ------------------------------------------------------------------
# classify each feature -> 'ground', 'underground', 'viaduct/bridge'
# ------------------------------------------------------------------
def classify(row):
    # any form of tunnel = underground
    if str(row.get("tunnel")).lower() not in ("nan", "none"):
        return "underground"
    # any form of bridge/viaduct
    if str(row.get("bridge")).lower() not in ("nan", "none"):
        return "viaduct"
    # layer < 0 also hints underground
    layer_val = row.get("layer")
    if layer_val is not None and str(layer_val).strip() and float(layer_val) < 0:
        return "underground"
    return "ground"

gdf["position"] = gdf.apply(classify, axis=1)

# colour palette requested by the user
colour = {"ground": "blue", "underground": "black", "viaduct": "red"}

fig, ax = plt.subplots(figsize=(8, 10))

for pos, subset in gdf.groupby("position"):
    subset.plot(ax=ax, linewidth=0.4, color=colour[pos], label=pos)

ax.set_title("Belgium rail layer – coloured by vertical position")
ax.set_axis_off()
ax.legend(loc="lower left")

plt.tight_layout()
# Out:
# /var/folders/_k/9xjyljgs0f763brjmdsjbd080000gn/T/ipykernel_33183/3058490621.py:35: UserWarning: Legend does not support handles for PatchCollection instances.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#implementing-a-custom-legend-handler
#   ax.legend(loc="lower left")

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# Load the Belgian rail layer (adjust path if you've stored it elsewhere)
gdf = gpd.read_file("../data/raw/rail_ch.gpkg", layer="rail")


# ------------------------------------------------------------------
# classify each feature -> 'ground', 'underground', 'viaduct/bridge'
# ------------------------------------------------------------------
def classify(row):
    # any form of tunnel = underground
    if str(row.get("tunnel")).lower() not in ("nan", "none"):
        return "underground"
    # any form of bridge/viaduct
    if str(row.get("bridge")).lower() not in ("nan", "none"):
        return "viaduct"
    # layer < 0 also hints underground
    layer_val = row.get("layer")
    if layer_val is not None and str(layer_val).strip() and float(layer_val) < 0:
        return "underground"
    return "ground"

gdf["position"] = gdf.apply(classify, axis=1)

# colour palette requested by the user
colour = {"ground": "blue", "underground": "black", "viaduct": "red"}

fig, ax = plt.subplots(figsize=(8, 10))

for pos, subset in gdf.groupby("position"):
    subset.plot(ax=ax, linewidth=0.4, color=colour[pos], label=pos)

ax.set_title("Switzerland rail layer – coloured by vertical position")
ax.set_axis_off()
ax.legend(loc="lower left")

plt.tight_layout()
# Out:
# /var/folders/_k/9xjyljgs0f763brjmdsjbd080000gn/T/ipykernel_33183/1190720908.py:36: UserWarning: Legend does not support handles for PatchCollection instances.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#implementing-a-custom-legend-handler
#   ax.legend(loc="lower left")

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# Load the Belgian rail layer (adjust path if you've stored it elsewhere)
gdf = gpd.read_file("../data/raw/rail_lux.gpkg", layer="rail")


# ------------------------------------------------------------------
# classify each feature -> 'ground', 'underground', 'viaduct/bridge'
# ------------------------------------------------------------------
def classify(row):
    # any form of tunnel = underground
    if str(row.get("tunnel")).lower() not in ("nan", "none"):
        return "underground"
    # any form of bridge/viaduct
    if str(row.get("bridge")).lower() not in ("nan", "none"):
        return "viaduct"
    # layer < 0 also hints underground
    layer_val = row.get("layer")
    if layer_val is not None and str(layer_val).strip() and float(layer_val) < 0:
        return "underground"
    return "ground"

gdf["position"] = gdf.apply(classify, axis=1)

# colour palette requested by the user
colour = {"ground": "blue", "underground": "black", "viaduct": "red"}

fig, ax = plt.subplots(figsize=(8, 10))

for pos, subset in gdf.groupby("position"):
    subset.plot(ax=ax, linewidth=0.4, color=colour[pos], label=pos)

ax.set_title("Lux rail layer – coloured by vertical position")
ax.set_axis_off()
ax.legend(loc="lower left")

plt.tight_layout()

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# Load the Belgian rail layer (adjust path if you've stored it elsewhere)
gdf = gpd.read_file("../data/raw/rail_po.gpkg", layer="rail")


# ------------------------------------------------------------------
# classify each feature -> 'ground', 'underground', 'viaduct/bridge'
# ------------------------------------------------------------------
def classify(row):
    # any form of tunnel = underground
    if str(row.get("tunnel")).lower() not in ("nan", "none"):
        return "underground"
    # any form of bridge/viaduct
    if str(row.get("bridge")).lower() not in ("nan", "none"):
        return "viaduct"
    # layer < 0 also hints underground
    layer_val = row.get("layer")
    if layer_val is not None and str(layer_val).strip() and float(layer_val) < 0:
        return "underground"
    return "ground"

gdf["position"] = gdf.apply(classify, axis=1)

# colour palette requested by the user
colour = {"ground": "blue", "underground": "black", "viaduct": "red"}

fig, ax = plt.subplots(figsize=(8, 10))

for pos, subset in gdf.groupby("position"):
    subset.plot(ax=ax, linewidth=0.4, color=colour[pos], label=pos)

ax.set_title("Portugal rail layer – coloured by vertical position")
ax.set_axis_off()
ax.legend(loc="lower left")

plt.tight_layout()
